# %% [markdown]
# ## Week 4 Homework
#
# #### Follow the prompts below to practice the concepts learned in Week 4's lectures. Submit the assignment as a .ipynb through blackboard.

# %%
import pandas as pd #pandas import
import numpy as np #numpy import
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None) #displays all columns instead of a max of 20
#pd.set_option('display.max_rows', None) #displays all rows instead of a max of 20

# %% [markdown]
# ##### Prompt 1
#
# Read in the file called 'Week 3 HW Output.xlsx'. Print the last 5 rows using the .tail() command.
#
# In the previous homework, I asked for a comparison of average fruit. Create a plot that allows you to visually compare average cost of fruit across years.

# %% [markdown]
# ##### Prompt 2
# Create a plot that shows the average cost of vegetables in each country.

# %% [markdown]
# ##### Prompt 3
# While the plot above can be informative, it is also very busy, limiting its utility. Let's try to group the countries again to simplify our visualizations.
#
# Read in the file called 'continentinfo.csv'. Merge this DataFrame with our Cost of Living DataFrame so that only countries in our Cost of Living DataFrame are present in the resulting DataFrame.
#
# Check for missing data and describe a course of action you may take to remedy this issue (Note: you do not have to take any steps).

# %% [markdown]
# ##### Prompt 4
#
# Recreate the plot in Prompt 2 using continent instead of country. Interpret the results.

# %% [markdown]
# Interpretation:

# %% [markdown]
# ##### Prompt 5
# Recreate the plot from Prompt 4 but now with two plots, one displaying data from 2021 and the other displaying data from 2022.
#
# Are there any differences to note?

# %% [markdown]
# ##### Prompt 6
#
# Create a four panel plot that displays the distributions for:
#
#
# 1.   Avg_Fruit in the first plot on the first row
# 2.   Avg_Veg in the second plot on the first row
# 3.   Beef in the first plot on the second row
# 4.   Chicken in the second plot on the second row
#
# Make sure the plots each contain a title and they all share the same y axis.
#
# What do these plots tell you about the distributions of these variables and potential outliers?

# %% [markdown]
# ##### Prompt 7
# Now that we know a little about the distribution of some of our variables, create a plot that would allow you to visually evaluate the relationship between Avg_Veg and Avg_Fruit.
#
# Interpret the result. Be careful to not use absolute language since we have not tested this relationship.

# %% [markdown]
# ##### Prompt 8
#
# While mean is a measure of central tendency (and what is displayed in our bar graphs above), the above scatterplot, along with our distribution plots, suggests there may be some outliers in our data set for Avg Fruit and Avg Veg.
#
# We will pick one to investigate further by creating a plot that can help us gauge some information about the distribution of average veg by continent to see where the outliers may be influencing our results.
#
# Provide an explanation of whether the outliers are influencing our results based on the information displayed in the plot compared to the pattern of results displayed in our bar plots from prompt 4.

# %% [markdown]
# ##### Prompt 9
# Create a plot that would allow you to visually evaluate the relationship between Beef and Chicken.
#
# Interpret the result. Be careful to not use absolute language since we have not tested this relationship.

# %% [markdown]
# ##### Prompt 10
#
# Similar to prompt 8, the above plot coupled with our distribution plots suggest there are some outliers in our data for Beef and Chicken.
#
# Recreate similar plots that you created in prompt 8, but this time displaying the price of beef by continent.
#
# Once you create this plot, you will notice that there is one continent with a lot of outliers. To dig a little further, create a bar plot of all the countries in that continent to determine what may be driving these results.
#
# Explain your findings.
