# %% [markdown]
# ## Data Cleaning and Aggregating ICA
#
# #### Follow the prompts below to practice the concepts learned in the Data Cleaning and Aggregating lecture. Submit the assignment as a .ipynb through blackboard.

# %%
import pandas as pd #pandas import
import numpy as np #numpy import
pd.set_option('display.max_columns', None) #displays all columns instead of a max of 20

from google.colab import drive
drive.mount('/content/gdrive')

import os
os.getcwd()
os.chdir('/content/gdrive/My Drive/Python Course/Fall 2023 _ 10 week/Week 3')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ##### Prompt 1
#
# Read in the data file called 'Intro to Pandas ICA Output'.
#
# Print the first 5 rows by using the .head() command.

# %%
BMN=pd.read_excel(r'Intro to Pandas ICA Output.xlsx')
BMN.head()
# Out:
#                                       TITLE  RELEASE_YEAR  SCORE  \
# 0  David Attenborough: A Life on Our Planet          2020    9.0
# 1                                 Inception          2010    8.8
# 2                              Forrest Gump          1994    8.8
# 3                                Anbe Sivam          2003    8.7
# 4                        Bo Burnham: Inside          2021    8.7
#
#    NUMBER_OF_VOTES  DURATION   MAIN_GENRE MAIN_PRODUCTION  \
# 0            31180        83  documentary              GB
# 1          2268288       148        scifi              GB
# 2          1994599       142        drama              US
# 3            20595       160       comedy              IN
# 4            44074        87       comedy              US
#
#      Genre_description       Century
# 0                  NaN  21st Century
# 1                  NaN  21st Century
# 2                  NaN  20th Century
# 3  This movie is funny  21st Century
# 4  This movie is funny  21st Century

# %% [markdown]
# ##### Prompt 2
#
# The Variable Genre_description is missing values. Fill all missing values with 'This movie is neither funny nor scary'.
#
# Output your data frame.

# %%
BMN['Genre_description']=BMN['Genre_description'].fillna('This movie is neither funny nor scary')
BMN
# Out:
#                                         TITLE  RELEASE_YEAR  SCORE  \
# 0    David Attenborough: A Life on Our Planet          2020    9.0
# 1                                   Inception          2010    8.8
# 2                                Forrest Gump          1994    8.8
# 3                                  Anbe Sivam          2003    8.7
# 4                          Bo Burnham: Inside          2021    8.7
# ..                                        ...           ...    ...
# 384                                  The Trip          2021    6.9
# 385                                  The Dirt          2019    6.9
# 386                                   Top Gun          1986    6.9
# 387                               Radhe Shyam          2022    6.9
# 388                       Sorry to Bother You          2018    6.9
#
#      NUMBER_OF_VOTES  DURATION   MAIN_GENRE MAIN_PRODUCTION  \
# 0              31180        83  documentary              GB
# 1            2268288       148        scifi              GB
# 2            1994599       142        drama              US
# 3              20595       160       comedy              IN
# 4              44074        87       comedy              US
# ..               ...       ...          ...             ...
# 384            19706       113       comedy              NO
# 385            47603       108        drama              US
# 386           329656       110        drama              US
# 387            21328       138      romance              IN
# 388            75653       111      fantasy              US
#
#                          Genre_description       Century
# 0    This movie is neither funny nor scary  21st Century
# 1    This movie is neither funny nor scary  21st Century
# 2    This movie is neither funny nor scary  20th Century
# 3                      This movie is funny  21st Century
# 4                      This movie is funny  21st Century
# ..                                     ...           ...
# 384                    This movie is funny  21st Century
# 385  This movie is neither funny nor scary  21st Century
# 386  This movie is neither funny nor scary  20th Century
# 387  This movie is neither funny nor scary  21st Century
# 388  This movie is neither funny nor scary  21st Century
#
# [389 rows x 9 columns]

# %% [markdown]
# ##### Prompt 3
# What genres of movies are present in both the 20th century and 21st century movies?

# %%
BMN20=set(BMN['MAIN_GENRE'][BMN['Century']=='20th Century'])
print(BMN20)
BMN21=set(BMN['MAIN_GENRE'][BMN['Century']=='21st Century'])
print(BMN21)
BMN20.intersection(BMN21)
# Out:
# {'action', 'war', 'drama', 'scifi', 'horror', 'crime', 'comedy', 'western', 'thriller', 'romance'}
# {'action', 'war', 'sports', 'drama', 'musical', 'scifi', 'fantasy', 'animation', 'horror', 'crime', 'documentary', 'comedy', 'western', 'thriller', 'romance'}
# {'action',
#  'comedy',
#  'crime',
#  'drama',
#  'horror',
#  'romance',
#  'scifi',
#  'thriller',
#  'war',
#  'western'}

# %% [markdown]
# ##### Prompt 4
# Test to see if there are any duplicate columns. Print the duplicate rows.
#
# Then remove the duplicates.

# %%
print(BMN[BMN.duplicated()])
BMN=BMN.drop_duplicates()
# Out:
#                 TITLE  RELEASE_YEAR  SCORE  NUMBER_OF_VOTES  DURATION  \
# 99      Life of Brian          1979    8.0           392419        94
# 151  Bonnie and Clyde          1967    7.7           111189       110
#
#     MAIN_GENRE MAIN_PRODUCTION                      Genre_description  \
# 99      comedy              GB                    This movie is funny
# 151      drama              US  This movie is neither funny nor scary
#
#           Century
# 99   20th Century
# 151  20th Century

# %% [markdown]
# ##### Prompt 5
# I have provided a list the contains the country names corresponding to MAIN_PRODUCTION when the unique values of MAIN_PRODUCTION are sorted alphabetically. Create a dictionary with the unique values of MAIN_PRODUCTION (we obtained these in week 1) as keys and the provided list as values.

# %%
Countrylist=['Argentina','Australia','Belgium','Brazil','Canada','Congo, Democratic Republic','China','Germany','Denmark','Spain','France','United Kingdom','Hong Kong','Hungary','Indonesia','Ireland','India','Italy','Japan','Cambodia','Korea, Republic','Lithuania','Malawi','Mexico','Netherlands','Norway','New Zealand','Poland','Palestine','Thailand','Turkey','Ukraine','United States','Unknown','South Africa']
UniProd = sorted(set(BMN['MAIN_PRODUCTION']))
CountryDict=dict(zip(UniProd,Countrylist))
CountryDict
# Out:
# {'AR': 'Argentina',
#  'AU': 'Australia',
#  'BE': 'Belgium',
#  'BR': 'Brazil',
#  'CA': 'Canada',
#  'CD': 'Congo, Democratic Republic',
#  'CN': 'China',
#  'DE': 'Germany',
#  'DK': 'Denmark',
#  'ES': 'Spain',
#  'FR': 'France',
#  'GB': 'United Kingdom',
#  'HK': 'Hong Kong',
#  'HU': 'Hungary',
#  'ID': 'Indonesia',
#  'IE': 'Ireland',
#  'IN': 'India',
#  'IT': 'Italy',
#  'JP': 'Japan',
#  'KH': 'Cambodia',
#  'KR': 'Korea, Republic',
#  'LT': 'Lithuania',
#  'MW': 'Malawi',
#  'MX': 'Mexico',
#  'NL': 'Netherlands',
#  'NO': 'Norway',
#  'NZ': 'New Zealand',
#  'PL': 'Poland',
#  'PS': 'Palestine',
#  'TH': 'Thailand',
#  'TR': 'Turkey',
#  'UA': 'Ukraine',
#  'US': 'United States',
#  'XX': 'Unknown',
#  'ZA': 'South Africa'}

# %% [markdown]
# ##### Prompt 6
#
# Use the dictionary you created in Prompt 6 to create a new column called 'Country_LF' (LF stands for 'Long Form') by mapping the dictionary to the current 'MAIN_PRODUCTION' column.

# %%
BMN['Country_LF']=BMN.MAIN_PRODUCTION.map(CountryDict)
BMN
# Out:
# <ipython-input-8-c1f20826b0e5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BMN['Country_LF']=BMN.MAIN_PRODUCTION.map(CountryDict)
#                                         TITLE  RELEASE_YEAR  SCORE  \
# 0    David Attenborough: A Life on Our Planet          2020    9.0
# 1                                   Inception          2010    8.8
# 2                                Forrest Gump          1994    8.8
# 3                                  Anbe Sivam          2003    8.7
# 4                          Bo Burnham: Inside          2021    8.7
# ..                                        ...           ...    ...
# 384                                  The Trip          2021    6.9
# 385                                  The Dirt          2019    6.9
# 386                                   Top Gun          1986    6.9
# 387                               Radhe Shyam          2022    6.9
# 388                       Sorry to Bother You          2018    6.9
#
#      NUMBER_OF_VOTES  DURATION   MAIN_GENRE MAIN_PRODUCTION  \
# 0              31180        83  documentary              GB
# 1            2268288       148        scifi              GB
# 2            1994599       142        drama              US
# 3              20595       160       comedy              IN
# 4              44074        87       comedy              US
# ..               ...       ...          ...             ...
# 384            19706       113       comedy              NO
# 385            47603       108        drama              US
# 386           329656       110        drama              US
# 387            21328       138      romance              IN
# 388            75653       111      fantasy              US
#
#                          Genre_description       Century      Country_LF
# 0    This movie is neither funny nor scary  21st Century  United Kingdom
# 1    This movie is neither funny nor scary  21st Century  United Kingdom
# 2    This movie is neither funny nor scary  20th Century   United States
# 3                      This movie is funny  21st Century           India
# 4                      This movie is funny  21st Century   United States
# ..                                     ...           ...             ...
# 384                    This movie is funny  21st Century          Norway
# 385  This movie is neither funny nor scary  21st Century   United States
# 386  This movie is neither funny nor scary  20th Century   United States
# 387  This movie is neither funny nor scary  21st Century           India
# 388  This movie is neither funny nor scary  21st Century   United States
#
# [387 rows x 10 columns]

# %% [markdown]
# ##### Prompt 7
#
# Read in the file called 'raw_titles'. This file contains some additional information about our Movies along with Netflix shows.
#
# Keep only the columns called 'title' and 'age_certification'

# %%
RT=pd.read_csv(r'raw_titles.csv')
RT1=RT[['title','age_certification']]
RT1
# Out:
#                                     title age_certification
# 0     Five Came Back: The Reference Films             TV-MA
# 1                             Taxi Driver                 R
# 2         Monty Python and the Holy Grail                PG
# 3                           Life of Brian                 R
# 4                            The Exorcist                 R
# ...                                   ...               ...
# 5801                       Edis Starlight               NaN
# 5802                                Clash               NaN
# 5803                       Shadow Parties               NaN
# 5804   Mighty Little Bheem: Kite Festival               NaN
# 5805                         The Platform             TV-14
#
# [5806 rows x 2 columns]

# %% [markdown]
# ##### Prompt 8
#
# Merge the DataFrame with the age certification with our Movie DataFrame so that only Titles present in the Movie DataFrame are present in the resulting DataFrame.

# %%
BMN2=pd.merge(BMN,RT1,left_on='TITLE',right_on='title',how='left')
BMN2
# Out:
#                                         TITLE  RELEASE_YEAR  SCORE  \
# 0    David Attenborough: A Life on Our Planet          2020    9.0
# 1                                   Inception          2010    8.8
# 2                                Forrest Gump          1994    8.8
# 3                                  Anbe Sivam          2003    8.7
# 4                          Bo Burnham: Inside          2021    8.7
# ..                                        ...           ...    ...
# 392                                  The Trip          2021    6.9
# 393                                  The Dirt          2019    6.9
# 394                                   Top Gun          1986    6.9
# 395                               Radhe Shyam          2022    6.9
# 396                       Sorry to Bother You          2018    6.9
#
#      NUMBER_OF_VOTES  DURATION   MAIN_GENRE MAIN_PRODUCTION  \
# 0              31180        83  documentary              GB
# 1            2268288       148        scifi              GB
# 2            1994599       142        drama              US
# 3              20595       160       comedy              IN
# 4              44074        87       comedy              US
# ..               ...       ...          ...             ...
# 392            19706       113       comedy              NO
# 393            47603       108        drama              US
# 394           329656       110        drama              US
# 395            21328       138      romance              IN
# 396            75653       111      fantasy              US
#
#                          Genre_description       Century      Country_LF  \
# 0    This movie is neither funny nor scary  21st Century  United Kingdom
# 1    This movie is neither funny nor scary  21st Century  United Kingdom
# 2    This movie is neither funny nor scary  20th Century   United States
# 3                      This movie is funny  21st Century           India
# 4                      This movie is funny  21st Century   United States
# ..                                     ...           ...             ...
# 392                    This movie is funny  21st Century          Norway
# 393  This movie is neither funny nor scary  21st Century   United States
# 394  This movie is neither funny nor scary  20th Century   United States
# 395  This movie is neither funny nor scary  21st Century           India
# 396  This movie is neither funny nor scary  21st Century   United States
#
#                                         title age_certification
# 0    David Attenborough: A Life on Our Planet                PG
# 1                                   Inception             PG-13
# 2                                Forrest Gump             PG-13
# 3                                  Anbe Sivam               NaN
# 4                          Bo Burnham: Inside                 R
# ..                                        ...               ...
# 392                                  The Trip               NaN
# 393                                  The Dirt                 R
# 394                                   Top Gun                PG
# 395                               Radhe Shyam               NaN
# 396                       Sorry to Bother You                 R
#
# [397 rows x 12 columns]

# %% [markdown]
# ##### Prompt 9
#
# Print all rows that contain duplicate titles.
#
# Looking at the rows with the same titles, can you determine a possible cause for some of the duplicate rows?

# %%
#BMN2[BMN2['TITLE']==BMN2['TITLE'].duplicated('TITLE')]
#BMN2[])
#BMN2['TITLE'][BMN2['TITLE'].duplicated()]

BMN2[BMN2['TITLE'].isin(BMN2[BMN2.duplicated('TITLE')]['TITLE'])]

#BMN2[BMN2.duplicated()]['TITLE']
# Out:
#                                  TITLE  RELEASE_YEAR  SCORE  NUMBER_OF_VOTES  \
# 16                         Taxi Driver          1976    8.3           795222
# 17                         Taxi Driver          1976    8.3           795222
# 21                             Warrior          2011    8.2           463276
# 22                             Warrior          2011    8.2           463276
# 161                               Ludo          2020    7.6            37528
# 162                               Ludo          2020    7.6            37528
# 213          A Nightmare on Elm Street          1984    7.4           230543
# 214          A Nightmare on Elm Street          1984    7.4           230543
# 258                            Monster          2003    7.3           149218
# 259                            Monster          2003    7.3           149218
# 277                            Shooter          2007    7.2           329417
# 278                            Shooter          2007    7.2           329417
# 297                           The Call          2020    7.1            29450
# 298                           The Call          2020    7.1            29450
# 355                       The Platform          2019    7.0           207877
# 356                       The Platform          2019    7.0           207877
# 369  Cloudy with a Chance of Meatballs          2009    6.9           226225
# 370  Cloudy with a Chance of Meatballs          2009    6.9           226225
# 389                          Christine          2016    6.9            14977
# 390                          Christine          2016    6.9            14977
#
#      DURATION MAIN_GENRE MAIN_PRODUCTION  \
# 16        113      crime              US
# 17        113      crime              US
# 21        140      drama              US
# 22        140      drama              US
# 161       150      crime              IN
# 162       150      crime              IN
# 213        91     horror              US
# 214        91     horror              US
# 258       110      crime              US
# 259       110      crime              US
# 277       124   thriller              US
# 278       124   thriller              US
# 297       112   thriller              KR
# 298       112   thriller              KR
# 355        94     horror              ES
# 356        94     horror              ES
# 369        90  animation              US
# 370        90  animation              US
# 389       115      drama              US
# 390       115      drama              US
#
#                          Genre_description       Century       Country_LF  \
# 16   This movie is neither funny nor scary  20th Century    United States
# 17   This movie is neither funny nor scary  20th Century    United States
# 21   This movie is neither funny nor scary  21st Century    United States
# 22   This movie is neither funny nor scary  21st Century    United States
# 161  This movie is neither funny nor scary  21st Century            India
# 162  This movie is neither funny nor scary  21st Century            India
# 213                    This movie is scary  20th Century    United States
# 214                    This movie is scary  20th Century    United States
# 258  This movie is neither funny nor scary  21st Century    United States
# 259  This movie is neither funny nor scary  21st Century    United States
# 277                    This movie is scary  21st Century    United States
# 278                    This movie is scary  21st Century    United States
# 297                    This movie is scary  21st Century  Korea, Republic
# 298                    This movie is scary  21st Century  Korea, Republic
# 355                    This movie is scary  21st Century            Spain
# 356                    This movie is scary  21st Century            Spain
# 369  This movie is neither funny nor scary  21st Century    United States
# 370  This movie is neither funny nor scary  21st Century    United States
# 389  This movie is neither funny nor scary  21st Century    United States
# 390  This movie is neither funny nor scary  21st Century    United States
#
#                                  title age_certification
# 16                         Taxi Driver                 R
# 17                         Taxi Driver               NaN
# 21                             Warrior             PG-13
# 22                             Warrior             TV-MA
# 161                               Ludo               NaN
# 162                               Ludo             PG-13
# 213          A Nightmare on Elm Street                 R
# 214          A Nightmare on Elm Street                 R
# 258                            Monster                 R
# 259                            Monster                 R
# 277                            Shooter                 R
# 278                            Shooter             TV-14
# 297                           The Call                 R
# 298                           The Call               NaN
# 355                       The Platform               NaN
# 356                       The Platform             TV-14
# 369  Cloudy with a Chance of Meatballs                PG
# 370  Cloudy with a Chance of Meatballs             TV-Y7
# 389                          Christine                 R
# 390                          Christine                 R

# %% [markdown]
# It appears there were two ratings for some titles due to appear in theaters and on television.

# %% [markdown]
# ##### Prompt 10
#
# By happenstance (e.g., this will not always be the case), it appears that the television version of ratings are all the last entry for that title. Drop duplicates keeping the first value of each title.
#
# Then Group the titles by age_certification to determine which age_certification has the longest average duration.

# %%
BMN3=BMN2.drop_duplicates(subset=['TITLE'],keep='first')

# %%
BMN3.groupby('age_certification')['DURATION'].mean()
# Out:
#   File "<ipython-input-16-057dc9367aed>", line 1
#     BMN3['age_certification][BMN3.groupby('age_certification')['DURATION'].mean().max]
#                                                                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# Films rated G have the highested average durations

# %%
BMN3.to_excel('DCA ICA Output.xlsx',index=False)
