# %% [markdown]
# ## Data Visualizations ICA
#
#
# #### Follow the prompts below to practice the concepts learned in the Data Visualizations Lecture. Submit the assignment as a .ipynb through blackboard.

# %%
import pandas as pd #pandas import
import numpy as np #numpy import
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None) #displays all columns instead of a max of 20
pd.set_option('display.max_rows', None) #displays all rows instead of a max of 20

# %% [markdown]
# ##### Prompt 1
#
# Read in the file 'DCA ICA Output.xlsx'.

# %%
dca=pd.read_excel(r"DCA ICA Output.xlsx")
dca.head()
# Out:
#                                       TITLE  RELEASE_YEAR  SCORE  \
# 0  David Attenborough: A Life on Our Planet          2020    9.0
# 1                                 Inception          2010    8.8
# 2                              Forrest Gump          1994    8.8
# 3                                Anbe Sivam          2003    8.7
# 4                        Bo Burnham: Inside          2021    8.7
#
#    NUMBER_OF_VOTES  DURATION   MAIN_GENRE MAIN_PRODUCTION  \
# 0            31180        83  documentary              GB
# 1          2268288       148        scifi              GB
# 2          1994599       142        drama              US
# 3            20595       160       comedy              IN
# 4            44074        87       comedy              US
#
#                        Genre_description       Century      Country_LF  \
# 0  This movie is neither funny nor scary  21st Century  United Kingdom
# 1  This movie is neither funny nor scary  21st Century  United Kingdom
# 2  This movie is neither funny nor scary  20th Century   United States
# 3                    This movie is funny  21st Century           India
# 4                    This movie is funny  21st Century   United States
#
#                                       title age_certification
# 0  David Attenborough: A Life on Our Planet                PG
# 1                                 Inception             PG-13
# 2                              Forrest Gump             PG-13
# 3                                Anbe Sivam               NaN
# 4                        Bo Burnham: Inside                 R

# %% [markdown]
# ##### Prompt 2
#
# Are movies getting longer? Plot movie duration by year.

# %%
# fig=plt.figure(figsize=[10,10])
# # dca['RELEASE_YEAR']=dca['Year'].astype(str)+"_"+dca['Quarter'].astype(str)
# # sns.barplot(data=dca,x='RELEASE_YEAR',y='DURATION')

# fig=plt.figure(figsize=[10,10]) #or dca['decade'] = dca['RELEASE_YEAR'] // 10 * 10

# plt.figure(figsize=(10,5))
# dca.plot(kind='bar')
# plt.xlabel('Year by decades')
# plt.ylabel('Movie Duration')
# plt.title('Movie Duration by Decade')
# plt.show()
def get_decade(year: int):
    return str(year)[:-1]+"0"

# get_decade(2015)
dca['decade'] = dca["RELEASE_YEAR"].apply(get_decade)
dca['decade'].unique
# dca['decade'] = str(dca["RELEASE_YEAR"])[:-1]+"0"
# dca['decade'] = (dca['RELEASE_YEAR'] // 10) * 2
# dca['decade'].unique
# dca['RELEASE_YEAR'].unique
plt.figure(figsize=(10,5))
for decade, data in dca.groupby('decade'):
    plt.bar([decade], data['DURATION'].mean())

plt.xlabel('Decades')
plt.ylabel('Movie Duration-min')
plt.title('Movie Duration by Decades')
plt.show()

# %%
dca.query("decade == '1990'")
# Out:
#                                               TITLE  RELEASE_YEAR  SCORE  \
# 2                                      Forrest Gump          1994    8.8
# 5                               Saving Private Ryan          1998    8.6
# 57                                           Bombay          1995    8.1
# 67   Neon Genesis Evangelion: The End of Evangelion          1997    8.0
# 102                                         Gattaca          1997    7.8
# 110                                      Awakenings          1990    7.8
# 134                                   Donnie Brasco          1997    7.7
# 138                              Kuch Kuch Hota Hai          1998    7.6
# 145                            Kabhi Haan Kabhi Naa          1994    7.6
# 171                                        Dil Se..          1998    7.5
# 180                            The Devil's Advocate          1997    7.5
# 188                               Menace II Society          1993    7.5
# 189                          Hum Aapke Hain Koun..!          1994    7.5
# 226                               Girl, Interrupted          1999    7.3
# %%
plt.figure(figsize=(10,5))
sns.barplot(data=dca,x='age_certification',y='DURATION', errorbar=None)

plt.xlabel('Age Certification')
plt.ylabel('Movie Duration-min')
plt.title('Movie Duration by Age Duration')
plt.show()

# %% [markdown]
# ##### Prompt 4
# Recreate the plot above adding annotations for the actual average duration at the top of the bars.

# %%
plt.figure(figsize=(10,5))
plots=sns.barplot(data=dca,x='age_certification',y='DURATION', errorbar=None)
averages = dca['DURATION'].mean()

for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'), 
                   (bar.get_x() + bar.get_width() / 2., bar.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 10), 
                   textcoords = 'offset points')
    
plt.xlabel('Age Certification')
plt.ylabel('Movie Duration-min')
plt.title('Movie Duration by Age Duration')
plt.show()

# %% [markdown]
# ##### Prompt 5
#
# Create a stacked bar chart that shows the percentage of each Main Genre within each age_certification.

# %%
plt.figure(figsize=(10,5))
# dca = pd.DataFrame({
#    'age_certification',
#    'DURATION',
#    'MAIN_GENRE'
# })
dca_pivot = dca.pivot(index='age_certification', columns='MAIN_GENRE', values='DURATION')
dca_pivot.plot(kind='bar', stacked=True)

plt.xlabel('Age Certification')
plt.ylabel('Movie Duration-min')
plt.title('Movie Duration by Age Duration')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\alice\OneDrive\Documents\UofL\MSBA\MSBA605-Python\Homeworks and In-class\Data Visualization\Data Visualizations ICA_ALICE_TREJO.ipynb Cell 12 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/alice/OneDrive/Documents/UofL/MSBA/MSBA605-Python/Homeworks%20and%20In-class/Data%20Visualization/Data%20Visualizations%20ICA_ALICE_TREJO.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(10,5))
#       <a href='vscode-notebook-cell:/c%3A/Users/alice/OneDrive/Documents/UofL/MSBA/MSBA605-Python/Homeworks%20and%20In-class/Data%20Visualization/Data%20Visualizations%20ICA_ALICE_TREJO.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> dca = pd.DataFrame({
#       <a href='vscode-notebook-cell:/c%3A/Users/alice/OneDrive/Documents/UofL/MSBA/MSBA605-Python/Homeworks%20and%20In-class/Data%20Visualization/Data%20Visualizations%20ICA_ALICE_TREJO.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a>    'age_certification',
#       <a href='vscode-notebook-cell:/c%3A/Users/alice/OneDrive/Documents/UofL/MSBA/MSBA605-Python/Homeworks%20and%20In-class/Data%20Visualization/Data%20Visualizations%20ICA_ALICE_TREJO.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a>    'DURATION',
#       <a href='vscode-notebook-cell:/c%3A/Users/alice/OneDrive/Documents/UofL/MSBA/MSBA605-Python/Homeworks%20and%20In-class/Data%20Visualization/Data%20Visualizations%20ICA_ALICE_TREJO.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a>    'MAIN_GENRE'
#       <a href='vscode-notebook-cell:/c%3A/Users/alice/OneDrive/Documents/UofL/MSBA/MSBA605-Python/Homeworks%20and%20In-class/Data%20Visualization/Data%20Visualizations%20ICA_ALICE_TREJO.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> })
# ----> <a href='vscode-notebook-cell:/c%3A/Users/alice/OneDrive/Documents/UofL/MSBA/MSBA605-Python/Homeworks%20and%20In-class/Data%20Visualization/Data%20Visualizations%20ICA_ALICE_TREJO.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a> dca_pivot = dca.pivot(index='age_certification', columns='MAIN_GENRE', values='DURATION')
#       <a href='vscode-notebook-cell:/c%3A/Users/alice/OneDrive/Documents/UofL/MSBA/MSBA605-Python/Homeworks%20and%20In-class/Data%20Visualization/Data%20Visualizations%20ICA_ALICE_TREJO.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a> dca_pivot.plot(kind='bar', stacked=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/alice/OneDrive/Documents/UofL/MSBA/MSBA605-Python/Homeworks%20and%20In-class/Data%20Visualization/Data%20Visualizations%20ICA_ALICE_TREJO.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a> plt.xlabel('Age Certification')
#
# File c:\Users\alice\anaconda3\Lib\site-packages\pandas\core\frame.py:8414, in DataFrame.pivot(self, columns, index, values)
#    8409 @Substitution("")
#    8410 @Appender(_shared_docs["pivot"])
#    8411 def pivot(self, *, columns, index=lib.NoDefault, values=lib.NoDefault) -> DataFrame:
#    8412     from pandas.core.reshape.pivot import pivot
# -> 8414     return pivot(self, index=index, columns=columns, values=values)
#
# File c:\Users\alice\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:540, in pivot(data, columns, index, values)
#     538         index_list = [Series(data.index, name=data.index.name)]
#     539 else:
# --> 540     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     542 data_columns = [data[col] for col in columns_listlike]
#     543 index_list.extend(data_columns)
#
# File c:\Users\alice\anaconda3\Lib\site-packages\pandas\core\reshape\pivot.py:540, in <listcomp>(.0)
#     538         index_list = [Series(data.index, name=data.index.name)]
#     539 else:
# --> 540     index_list = [data[idx] for idx in com.convert_to_list_like(index)]
#     542 data_columns = [data[col] for col in columns_listlike]
#     543 index_list.extend(data_columns)
#
# File c:\Users\alice\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\alice\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:349, in RangeIndex.get_loc(self, key)
#     347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
# --> 349     raise KeyError(key)
#     350 self._check_indexing_error(key)
#     351 raise KeyError(key)
#
# KeyError: 'age_certification'

# %% [markdown]
# ##### Prompt 6
#
# The plot above is a little busy due to so many genre categories, we had addressed this issue in Week 1 by creating a new column called Genre_description. Recreate this plot but use our Genre Description instead of Main Genre.

# %% [markdown]
# ##### Prompt 7
#
# Create a plot that would facilitate your ability to visually evaluate whether there is a relationship between score and number of votes.

# %% [markdown]
# ##### Prompt 8
#
# Based on your plot above, you may notice something with the distribution of our data that is making it difficult to determine any true relationship. Create two plot, with one plot visualizing the distribution of Score and the other visualizing the distribution of Number of Votes. You can use the same type of plot, or different types if you want extra practice.
#
# What conclusions about your distributions can you draw from these plots?

# %% [markdown]
# ##### Prompt 9
#
# Use a single command to obtain a graphical representation of all the relationships between your numeric variables (and ask for the distirbution of each variable as well).
#
# Which pair of variables appear to have the strongest relationship?

# %% [markdown]
# ##### Prompt 10
# Create a plot, with one command, that displays the average duration for each of our genre description categories, for each age certification.
#
# Which age certification has the greatest difference in average duration based on genre description?
