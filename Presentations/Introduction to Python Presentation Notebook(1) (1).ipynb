# %% [markdown]
# #### Set Up
# - Follow McKinney 1.4 to download and follow the Anaconda installer
# - Make sure you can use Solstice Client to connect to monitors

# %% [markdown]
# ### Basic Programming with Python

# %% [markdown]
# #### Programming Environment
# - We will use the Anaconda distribution
#     - comes with preinstalled packages and environments useful for this course
# - Spyder
#
# ![Spyder.png](data:image/png;base64,...)
# - Jupyter
#
# ![Jupyter.png](data:image/png;base64,...)
#   - Jupyter Notebooks can also be open in Google Colaboratory
#     - need to map drive to be able to read in files from google drive:
#
#   ![image.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os
os.chdir('/content/gdrive/My Drive/Python Course/Fall 2023 _ 10 week/Week 3')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/gdrive')
#       4 import os
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# #### Resources
#
# - Presentation Notebooks
# - Previous Assignments
# - Videos on Blackboard (use Spyder)
# - Textbook
# - Github files associated with textbook
# - Google
#   - Stackoverflow
#   - GeeksforGeeks
#   - GitHub
#   - Other tutorials
# -Limit use of ChatGPT

# %% [markdown]
# #### Tips and Tricks
# - Control - Find for electronic resources
# - Copy/paste WHENEVER possible
# - Read errors carefully
# - Google exact error
# - Practice finding solutions to the problems you encounter independently
# - Practice editing code that you copy/paste to understand underworkings
# - If you want to understand how a command works, test its limitations
